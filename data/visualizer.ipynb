# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
import os
os.getcwd()
# Out:
# '/home/dema/Project/ProbRob/data'

# %%
calib_traj = pd.read_csv('calib_traj.csv', sep=';', index_col=None)
calib_traj
# Out:
#             x        y    theta
# 0     0.00000  0.00000  0.00000
# 1     0.00000  0.00000  0.00000
# 2     0.00000  0.00000  0.00000
# 3     0.00000  0.00000  0.00000
# 4     0.00000  0.00000  0.00000
# ...       ...      ...      ...
# 2430  1.76763 -4.05114 -1.10835
# 2431  1.76763 -4.05114 -1.10835
# 2432  1.76763 -4.05114 -1.10835
# 2433  1.76763 -4.05114 -1.10835
# 2434  1.76763 -4.05114 -1.10835
#
# [2435 rows x 3 columns]

# %%
data = pd.read_csv('calib_traj.csv', sep=';')
data = data.to_numpy()
plt.scatter(data[:, 0], data[:, 1], s=15)

# %%
data_gt = pd.read_csv('log/gt.csv', sep=';')
data_gt = data_gt.to_numpy()
plt.scatter(data_gt[:, 0], data_gt[:, 1], s=0.5, c='g')
plt.scatter(data[:, 0], data[:, 1], s=0.5)
