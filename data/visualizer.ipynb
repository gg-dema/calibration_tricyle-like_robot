# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
import os
os.getcwd()
os.listdir('log')
# Out:
# ['delta_ticks.csv',
#  'tick_readed.csv',
#  'GT.png',
#  'ticks.csv',
#  'odometry_wrong.png',
#  'v2t.png',
#  'original_tick.csv',
#  'tmp.csv',
#  'euler_integration.png',
#  'decoded_tick.csv']

# %%
plt.rcParams['figure.figsize'] = (10, 6)
plt.rcParams['figure.dpi'] = 150

# %%
path = 'tmp.csv'
#path = 'log/original_tick.csv'

data = pd.read_csv(path, sep=';', header=0, index_col=False)

# %%
plt.plot(data['steering'])

# %%
plt.plot(data['driving'])

# %%
os.listdir()
# Out:
# ['dataset.txt',
#  'non_formatted_dataset.txt',
#  'trajectory.csv',
#  'log',
#  'reconstructed_input.csv',
#  'visualizer.ipynb',
#  'tmp.csv']

# %%
path = 'reconstructed_input.csv'
#path = 'log/original_tick.csv'

data = pd.read_csv(path, sep=';', header=0, index_col=False)

# %%
plt.plot(data['steering'], linewidth=0.9)

# %%
traj = pd.read_csv('trajectory.csv', sep=';', header=0, index_col=False)
x = traj['x'].to_numpy()
y = traj['y'].to_numpy()
plt.plot(x, -y, linewidth=0.9)

# %%
plt.plot(x, -y, linewidth=0.9)

# %%
x = x*100
y = y*100

# %%
x1 = x[:len(x)//2]
x2 = x[len(x)//2:]

# %%
y1 = y[:len(y)//2]
y2 = y[len(y)//2:]

# %%
#plt.ylim(-15, 2.5)
#plt.xlim(0, 25)
plt.plot(x1, y1, label='1')
plt.plot(x2, y2, label='2')
plt.legend()

# %%
fig, axs = plt.subplots(2, 1, figsize=(10, 8))

# Plot data['driving']
axs[0].plot(data['Driving'])
axs[0].set_title('Data Driving')

# Plot data_delta['driving']
axs[1].plot(data_delta['Driving'])
axs[1].set_title('Data Delta Driving')

# Show the plots
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/.local/lib/python3.10/site-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Driving'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_5090/3635308140.py in <module>
#       6
#       7 # Plot data_delta['driving']
# ...

# %%
fig, axs = plt.subplots(2, 1, figsize=(10, 8))

# Plot data['driving']
axs[0].plot(data['Steer'])
axs[0].set_title('Data Steering')

# Plot data_delta['driving']
axs[1].plot(data_delta['Steer'])
axs[1].set_title('Data Delta Steering')

# Show the plots
plt.tight_layout()
plt.show()

# %%
# DATA reconstructed after avoiding encoder overflow
data_reconstruct_steer = pd.read_csv('log/decoded_tick.csv', sep=';', header=0)

fig, axs = plt.subplots(2, 1, figsize=(10, 8))

# Plot data['driving']
axs[0].plot(data_reconstruct_steer['Steer'][:-1])
axs[0].set_title('Data Steering reconstruct (as input to the model)')

# Plot data_delta['driving']
axs[1].plot(data_reconstruct_steer['Driving'][:-1])
axs[1].set_title('Data Driving reconstruct (as input tot the model)')

# Show the plots
plt.tight_layout()
plt.show()

# %%
traj = pd.read_csv('log/reconstructed_trajectory.csv', sep=';', header=0)
plt.plot(traj['x'].to_numpy(), traj['y'].to_numpy())
traj
# Out:
#              x         y     theta
# 0     0.000000  0.000000  0.000000
# 1     0.000000  0.000000  0.000000
# 2     0.000000  0.000000  0.000000
# 3     0.000000  0.000000  0.000000
# 4     0.000000  0.000000  0.000000
# ...        ...       ...       ...
# 2428 -0.253688 -0.253688 -0.253688
# 2429 -0.253688 -0.253688 -0.253688
# 2430 -0.253688 -0.253688 -0.253688
# 2431 -0.253688 -0.253688 -0.253688
# 2432 -0.253688 -0.253688 -0.253688
#
# [2433 rows x 3 columns]

# %%
traj = pd.read_csv('log/reconstructed_trajectory.csv', sep=';', header=0)
plt.plot(traj['x'].to_numpy(), traj['y'].to_numpy())
traj
# Out:
#              x         y     theta
# 0     0.000395 -0.003541 -0.003541
# 1    -0.003159 -0.007083 -0.007082
# 2    -0.006714 -0.010626 -0.010623
# 3    -0.010269 -0.014168 -0.014164
# 4    -0.013824 -0.017710 -0.017705
# ...        ...       ...       ...
# 2428  2.186120  2.388970  1.591940
# 2429  2.205080  2.548180  1.755580
# 2430  2.208310  2.676240  1.920510
# 2431  2.182250  2.786120  2.088020
# 2432  2.149890  2.865050  2.256810
#
# [2433 rows x 3 columns]
